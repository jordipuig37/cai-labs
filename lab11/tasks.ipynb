# %%
from igraph import Graph
from igraph import plot
import numpy as np
import matplotlib.pyplot as plt
from IPython import display

# %% [markdown]
# ## First task

# %%
p_vals = np.concatenate([[0], np.logspace(-3, 0)])

# %%
avg_len = []
clust_coef = []
val1 = 0
val2 = 0
N = 500 # we can vary N
for p in p_vals:
    watts = Graph.Watts_Strogatz(1, N, 2, p)
    if p == 0:
        val1 = watts.average_path_length()
        val2 = watts.transitivity_undirected()
    avg_len.append(watts.average_path_length() / val1)
    clust_coef.append(watts.transitivity_undirected() / val2)

# %%
plt.plot(p_vals, clust_coef)
plt.plot(p_vals, avg_len)
plt.xscale("log")

# %% [markdown]
# This should do it

# %% [markdown]
# ## Second task

# %%
# TODO

# %% [markdown]
# ## Third task

# %%
barabasi = Graph.Barabasi(100,2)

# %%
histogram = plt.hist(barabasi.degree(), bins=max(barabasi.degree()))

# %% [markdown]
# It's not much but it's honest work

# %%
m = 2
n0 = 100
n = 20
degrees = []
for i in range(n):
    for d in Graph.Barabasi(n, m).degree():
        degrees.append(d)

# %%
plt.hist(degrees)
# Out:
# (array([259.,  45.,  25.,  26.,  14.,   6.,  10.,   2.,   9.,   4.]),
#  array([ 2. ,  3.1,  4.2,  5.3,  6.4,  7.5,  8.6,  9.7, 10.8, 11.9, 13. ]),
#  <BarContainer object of 10 artists>)
