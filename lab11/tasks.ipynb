# %%
from igraph import Graph
from igraph import plot
import numpy as np
import matplotlib.pyplot as plt
from IPython import display

# %% [markdown]
# ## First task

# %%
k = 100
p_vals = np.concatenate([[0], np.logspace(-3, 0)])

# %%
avg_len = []
clust_coef = []
val1 = 0
val2 = 0
N = 500 # we can vary N
for p in p_vals:
    watts = Graph.Watts_Strogatz(1, N, 2, p)
    if p == 0:
        val1 = watts.average_path_length()
        val2 = watts.transitivity_undirected()
    avg_len.append(watts.average_path_length() / val1)
    clust_coef.append(watts.transitivity_undirected() / val2)

# %%
plt.plot(p_vals, clust_coef)
plt.plot(p_vals, avg_len)
plt.xscale("log")

# %% [markdown]
# This should do it

# %% [markdown]
# ## Second task

# %%
# TODO

# %% [markdown]
# ## Third task

# %%
barabasi = Graph.Barabasi(100,3)

# %%
plt.hist(barabasi.degree(), bins=max(barabasi.degree()))
plt.plot(l1,l2)

# %% [markdown]
# It's not much but it's honest work
