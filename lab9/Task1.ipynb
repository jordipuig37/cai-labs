# %%
from IPython.utils import io
import altair as alt
import pandas as pd
import numpy as np

# %% [markdown]
# # NO EJECUTAR
# El resultado está más abajo ya calculado

# %%
K, M = 30, 30
durations = [[0 for _ in range(M)] for _ in range(K)]
for k in range(1,K+1):
    for m in range(1,M+1):
        print('k=',k, ', m=', m, sep = '')
        with io.capture_output() as captured:
            # %run -i 'lsh.py' -k {k} -m {m}
        durations[k-1][m-1] = float(captured.stdout.split('\n')[-2].split(' ')[-2])
# Out:
# k=1, m=1
# k=1, m=2
# k=1, m=3
# k=1, m=4
# k=1, m=5
# k=1, m=6
# k=1, m=7
# k=1, m=8
# k=1, m=9
# k=1, m=10
# k=1, m=11
# k=1, m=12
# k=1, m=13
# k=1, m=14
# k=1, m=15
# k=1, m=16
# k=1, m=17
# k=1, m=18
# k=1, m=19
# k=1, m=20
# k=1, m=21
# k=1, m=22
# k=1, m=23
# k=1, m=24
# k=1, m=25
# k=1, m=26
# k=1, m=27
# k=1, m=28
# k=1, m=29
# k=1, m=30
# k=2, m=1
# k=2, m=2
# k=2, m=3
# k=2, m=4
# k=2, m=5
# k=2, m=6
# k=2, m=7
# k=2, m=8
# k=2, m=9
# k=2, m=10
# k=2, m=11
# k=2, m=12
# k=2, m=13
# k=2, m=14
# k=2, m=15
# k=2, m=16
# k=2, m=17
# k=2, m=18
# k=2, m=19
# k=2, m=20
# k=2, m=21
# k=2, m=22
# k=2, m=23
# k=2, m=24
# k=2, m=25
# k=2, m=26
# k=2, m=27
# k=2, m=28
# k=2, m=29
# k=2, m=30
# k=3, m=1
# k=3, m=2
# k=3, m=3
# k=3, m=4
# k=3, m=5
# k=3, m=6
# k=3, m=7
# k=3, m=8
# k=3, m=9
# k=3, m=10
# k=3, m=11
# k=3, m=12
# k=3, m=13
# k=3, m=14
# k=3, m=15
# k=3, m=16
# k=3, m=17
# k=3, m=18
# k=3, m=19
# k=3, m=20
# k=3, m=21
# k=3, m=22
# k=3, m=23
# k=3, m=24
# k=3, m=25
# ...

# %%
durations = [[0.03, 0.03, 0.03, 0.04, 0.05, 0.08, 0.08, 0.09, 0.11, 0.11, 0.12, 0.12, 0.16, 0.17, 0.18, 0.17, 0.19, 0.19, 0.22, 0.2, 0.23, 0.24, 0.24, 0.26, 0.26, 0.28, 0.33, 0.31, 0.31, 0.33],
 [0.02, 0.03, 0.05, 0.06, 0.09, 0.11, 0.14, 0.14, 0.16, 0.17, 0.19, 0.22, 0.25, 0.26, 0.28, 0.29, 0.31, 0.29, 0.33, 0.35, 0.35, 0.37, 0.37, 0.42, 0.42, 0.42, 0.46, 0.48, 0.49, 0.54],
 [0.02, 0.04, 0.06, 0.1, 0.12, 0.14, 0.16, 0.19, 0.2, 0.23, 0.23, 0.25, 0.28, 0.3, 0.32, 0.35, 0.41, 0.39, 0.43, 0.45, 0.5, 0.53, 0.54, 0.54, 0.55, 0.55, 0.57, 0.62, 0.65, 0.68],
 [0.13, 0.25, 0.38, 0.5, 0.63, 0.76, 0.89, 1.01, 1.13, 1.25, 1.39, 1.51, 1.64, 1.76, 1.88, 2.0, 2.14, 2.27, 2.42, 2.52, 2.65, 2.77, 2.89, 3.01, 3.15, 3.36, 3.44, 3.53, 3.68, 3.8],
 [0.13, 0.26, 0.4, 0.52, 0.65, 0.79, 0.91, 1.05, 1.17, 1.3, 1.44, 1.58, 1.73, 1.84, 1.97, 2.1, 2.23, 2.34, 2.47, 2.63, 2.74, 2.88, 3.03, 3.12, 3.31, 3.45, 3.52, 3.67, 3.84, 3.93],
 [0.14, 0.27, 0.41, 0.54, 0.67, 0.81, 0.95, 1.09, 1.22, 1.36, 1.54, 1.62, 1.8, 1.91, 2.1, 2.19, 2.35, 2.49, 2.63, 2.74, 3.24, 3.51, 6.14, 3.32, 3.4, 3.68, 5.94, 4.01, 4.0, 4.42],
 [0.16, 0.35, 0.5, 0.63, 0.74, 0.97, 0.99, 1.14, 1.27, 1.41, 1.56, 1.71, 1.86, 2.0, 2.12, 2.28, 2.4, 2.53, 2.68, 2.82, 3.06, 3.12, 3.29, 3.4, 3.52, 3.66, 3.83, 3.98, 4.13, 4.24],
 [0.15, 0.29, 0.44, 0.58, 0.73, 0.88, 1.03, 1.17, 1.31, 1.46, 1.6, 1.77, 1.92, 2.05, 2.18, 2.33, 2.48, 2.67, 2.82, 2.91, 3.09, 3.21, 3.37, 3.51, 3.65, 3.79, 3.98, 4.1, 4.24, 4.39],
 [0.15, 0.3, 0.45, 0.61, 0.75, 0.9, 1.08, 1.2, 1.36, 1.5, 1.65, 1.82, 2.24, 2.19, 2.53, 2.62, 2.73, 2.84, 3.08, 3.23, 3.3, 3.39, 3.51, 3.67, 3.75, 3.92, 4.09, 4.32, 4.42, 4.52],
 [0.15, 0.31, 0.46, 0.62, 0.78, 0.93, 1.13, 1.29, 1.42, 1.55, 1.73, 1.87, 2.04, 2.17, 2.33, 2.48, 2.64, 2.79, 2.98, 3.12, 3.27, 3.48, 3.67, 3.75, 4.1, 4.06, 4.2, 4.36, 4.75, 5.09]]

# %%
source = pd.DataFrame(durations)
source['k'] = source.index
source = source.melt(id_vars = 'k', var_name='m', value_name='time')

# %%
alt.Chart(source).mark_rect().encode(
    x=alt.X('k:O', axis=alt.Axis(labelAngle=0)),
    y='m:O',
    color='time:Q'
).transform_calculate(
    k = 'datum.k+1',
    m = 'datum.m+1'
).properties(width=300, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# # NO EJECUTAR
# El resultado está más abajo ya calculado

# %%
K, M = 30, 30
candidates = [[0 for _ in range(M)] for _ in range(K)]
for k in range(1,K+1):
    for m in range(1,M+1):
        print('k=',k, ', m=', m, sep = '')
        with io.capture_output() as captured:
            # %run -i 'lsh.py' -k {k} -m {m}
        cands = [int(captured.stdout.split('\n')[1:-2][1].split()[2]) for i in range(10)]
        candidates[k-1][m-1] = np.mean(cands)
# Out:
# k=1, m=1
# k=1, m=2
# k=1, m=3
# k=1, m=4
# k=1, m=5
# k=1, m=6
# k=1, m=7
# k=1, m=8
# k=1, m=9
# k=1, m=10
# k=1, m=11
# k=1, m=12
# k=1, m=13
# k=1, m=14
# k=1, m=15
# k=1, m=16
# k=1, m=17
# k=1, m=18
# k=1, m=19
# k=1, m=20
# k=1, m=21
# k=1, m=22
# k=1, m=23
# k=1, m=24
# k=1, m=25
# k=1, m=26
# k=1, m=27
# k=1, m=28
# k=1, m=29
# k=1, m=30
# k=2, m=1
# k=2, m=2
# k=2, m=3
# k=2, m=4
# k=2, m=5
# k=2, m=6
# k=2, m=7
# k=2, m=8
# k=2, m=9
# k=2, m=10
# k=2, m=11
# k=2, m=12
# k=2, m=13
# k=2, m=14
# k=2, m=15
# k=2, m=16
# k=2, m=17
# k=2, m=18
# k=2, m=19
# k=2, m=20
# k=2, m=21
# k=2, m=22
# k=2, m=23
# k=2, m=24
# k=2, m=25
# k=2, m=26
# k=2, m=27
# k=2, m=28
# k=2, m=29
# k=2, m=30
# k=3, m=1
# k=3, m=2
# k=3, m=3
# k=3, m=4
# k=3, m=5
# k=3, m=6
# k=3, m=7
# k=3, m=8
# k=3, m=9
# k=3, m=10
# k=3, m=11
# k=3, m=12
# k=3, m=13
# k=3, m=14
# k=3, m=15
# k=3, m=16
# k=3, m=17
# k=3, m=18
# k=3, m=19
# k=3, m=20
# k=3, m=21
# k=3, m=22
# k=3, m=23
# k=3, m=24
# k=3, m=25
# ...

# %%
candidates = [[1001.0, 1148.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0], [1001.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0], [973.0, 1062.0, 1337.0, 1477.0, 1492.0, 1494.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0], [971.0, 1063.0, 1283.0, 1420.0, 1430.0, 1476.0, 1488.0, 1492.0, 1492.0, 1492.0, 1494.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0], [333.0, 471.0, 1132.0, 1182.0, 1298.0, 1348.0, 1439.0, 1442.0, 1462.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0], [333.0, 1067.0, 1128.0, 1288.0, 1375.0, 1407.0, 1407.0, 1492.0, 1494.0, 1494.0, 1494.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0], [327.0, 1064.0, 1125.0, 1189.0, 1358.0, 1364.0, 1491.0, 1493.0, 1493.0, 1494.0, 1494.0, 1495.0, 1495.0, 1495.0, 1496.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500.0], [327.0, 808.0, 877.0, 1000.0, 1015.0, 1149.0, 1281.0, 1286.0, 1326.0, 1347.0, 1368.0, 1371.0, 1371.0, 1468.0, 1469.0, 1471.0, 1472.0, 1474.0, 1482.0, 1482.0, 1483.0, 1483.0, 1485.0, 1485.0, 1485.0, 1485.0, 1485.0, 1485.0, 1486.0, 1486.0], [312.0, 466.0, 704.0, 932.0, 948.0, 1181.0, 1197.0, 1249.0, 1263.0, 1281.0, 1281.0, 1308.0, 1329.0, 1346.0, 1348.0, 1354.0, 1380.0, 1415.0, 1415.0, 1416.0, 1418.0, 1418.0, 1419.0, 1419.0, 1422.0, 1424.0, 1424.0, 1440.0, 1442.0, 1455.0], [100.0
, 44.0, 44.0, 44.0, 44.0, 51.0, 52.0, 52.0, 52.0, 57.0, 61.0, 67.0, 67.0, 73.0, 74.0, 75.0], [5.0, 5.0, 12.0, 13.0, 14.0, 33.0, 33.0, 33.0, 33.0, 39.0, 41.0, 43.0, 44.0, 44.0, 44.0, 44.0, 45.0, 46.0, 47.0, 48.0, 59.0, 59.0, 59.0, 60.0, 63.0, 64.0, 68.0, 70.0, 71.0, 71.0]]

# %%
source = pd.DataFrame(candidates)
source['k'] = source.index
source = source.melt(id_vars = 'k', var_name='m', value_name='num_cand')

# %%
selectorM = alt.selection_single(fields=['m'])
selectorK = alt.selection_single(fields=['k'])
selectorKM = alt.selection_single(fields=['k', 'm'])

col = alt.Color('num_cand:Q', scale=alt.Scale(scheme='blueorange'))
color = alt.condition(((alt.datum.k <= selectorKM.k) & (alt.datum.k >= selectorKM.k)) 
                      | ((alt.datum.m <= selectorKM.m) & (alt.datum.m >= selectorKM.m)),
                      alt.value('lightgray'), col)

base = alt.Chart(source).transform_calculate(
    k = 'datum.k+1',
    m = 'datum.m+1'
).properties(width=200, height=200)

heatmap = base.mark_rect().encode(
    x=alt.X('k:O', axis=alt.Axis(labelAngle=0)),
    y='m:O',
    color=color
).add_selection(selectorM).add_selection(selectorK).add_selection(selectorKM)

lineK = base.mark_line().encode(
    x=alt.X('k:O', axis=alt.Axis(labelAngle=0)),
    y='num_cand:Q'
).transform_filter(selectorM)

lineM = base.mark_line().encode(
    y='m:O',
    x='num_cand:Q'
).transform_filter(selectorK)

(heatmap | lineM) & lineK
# Out:
# alt.VConcatChart(...)

# %%
K, M = 30, 30
s, N = 0.8, 1500
theoretical = [[(1-(1-s**k)**m)*N for m in range(1,M+1)] for k in range(1,K+1)]

# %%
sourceT = pd.DataFrame(theoretical)
sourceT['k'] = sourceT.index
sourceT = sourceT.melt(id_vars = 'k', var_name='m', value_name='num_cand')

# %%
selectorM = alt.selection_single(fields=['m'])
selectorK = alt.selection_single(fields=['k'])
selectorKM = alt.selection_single(fields=['k', 'm'])

col = alt.Color('num_cand:Q', scale=alt.Scale(scheme='blueorange'))
color = alt.condition(((alt.datum.k <= selectorKM.k) & (alt.datum.k >= selectorKM.k)) 
                      | ((alt.datum.m <= selectorKM.m) & (alt.datum.m >= selectorKM.m)),
                      alt.value('lightgray'), col)

base = alt.Chart(sourceT).transform_calculate(
    k = 'datum.k+1',
    m = 'datum.m+1'
).properties(width=200, height=200)

heatmap = base.mark_rect().encode(
    x=alt.X('k:O', axis=alt.Axis(labelAngle=0)),
    y='m:O',
    color=color
).add_selection(selectorM).add_selection(selectorK).add_selection(selectorKM)

lineK = base.mark_line().encode(
    x=alt.X('k:O', axis=alt.Axis(labelAngle=0)),
    y='num_cand:Q'
).transform_filter(selectorM)

lineM = base.mark_line().encode(
    y='m:O',
    x='num_cand:Q'
).transform_filter(selectorK)

(heatmap | lineM) & lineK
# Out:
# alt.VConcatChart(...)
